# %% [markdown]
# Discutimos un problema de optimizacion de cartera que esta ocurriendo en el mercado energetico.
# Los servicios publicos de distribucion de energia tienen que decidir que parte de la demanda de energia solicitada
# debe producirse en su propia planta de energia y que cantidad complementaria debe comprarse en el mercado al contado
# y en los contratos posteriores a la carga.
#
# # Modelo Equivalente a Energy Portfolio Optimization for Electric Utilities
#
# \begin{align}
# \text{minimize} \qquad & c^{tot} \\
#  \text{subject to} \quad \quad & c^{tot}= c^{PP} + c^{SM} + c^{LFC} \quad eq(6)\\
#  \qquad \qquad & p_t^{PP} + p_t^{SM} + p_t^{LFC} = P_t  \quad t=1,..,N^T\quad eq(23)\\
#  \qquad \qquad & c^{PP} = C_{fix}^{PP} + C_{var}^{PP}\sum_{t=1}^{N^T}\frac{1}{4}p_t^{PP} \quad eq(7\&8)\\
#  \qquad \qquad & p_t^{PP} = P_{max}^{PP}\sum_{m=2}^{N^M}\frac{1}{10}(m+2)\delta_{mt} \quad t=1,..,N^T\quad eq(26)\\
#  \qquad \qquad & \sum_{m=1}^{N^M}\delta_{mt} = 1 \quad t=1,..,N^T\quad eq(25)\\
#  \qquad \qquad & \chi_t^{S} \geq \delta_{mt} - \delta_{mt-1} \quad \forall m\quad t=2,..,N^T\quad eq(27)\\
#  \qquad \qquad & \chi_t^{S} \geq \delta_{mt-1} - \delta_{mt} \quad \forall m\quad t=2,..,N^T\quad eq(28)\\
#  \qquad \qquad & \sum_{k=1}^{D_{act}^{PP}} \chi_{t+k-1}^{S} \leq 1 \quad t=1,..,N^T-(D_{act}^{PP}-1) \quad eq(29)\\
# \qquad \qquad & \chi_t^{I} \geq \delta_{1t-1} - \delta_{1t} \quad t=2,..,N^T \quad eq(30)\\
#  \qquad \qquad & \sum_{k=1}^{D_{idl}^{PP}} \chi_{t+k-1}^{I} \leq 1 \quad t=1,..,N^T-(D_{idl}^{PP}-1) \quad eq(31)\\
#  \qquad \qquad & c^{SM} = 24C^{BL}\alpha + 12C^{PL}\beta \quad eq(12)\\
#  \qquad \qquad & p_t^{SM} = \alpha +I_t^{PL}\beta \quad eq(9)\\
#  \qquad \qquad & c^{LFC} = \sum_{b=1}^{N^B}(C_b^{LFC}\mu_b +P_b^{LFC}e_b^{LFC}) \quad eq(14\&21)\\
#  \qquad \qquad & e^{LFC} = \sum_{t=1}^{N^T}\frac{1}{4}p_t^{LFC} \quad eq(16)\\
#  \qquad \qquad & \sum_{b=1}^{N^{B}}\mu_b = 1 \quad eq(18)\\
#  \qquad \qquad & e^{LFC} = \sum_{b=2}^{N^B}Z_{b-1}^{d}\mu_b  + \sum_{b=1}^{N^B}e_{b}^{LFC} \quad eq(19)\\
#  \qquad \qquad & e_b^{LFC} \leq (Z_b^d-Z_{b-1}^d)\mu_b \quad b=1,..,N^{B}\quad eq(20)\\
# \qquad \qquad & c^{tot}, c^{PP}, e^{PP},c^{SM},e^{SM},c^{LFC},e^{LFC} \in \mathbb{R}^+\\
# \qquad \qquad & p_t^{PP},p_t^{SM},p_t^{LFC} \in \mathbb{R}^+ \forall t\\
# \qquad \qquad & \delta_{mt} \in \{0,1\} \forall t,m\\
# \qquad \qquad & \chi_t^{S},\chi_t^{I} \in \mathbb{R}^+ \forall t\\
# \qquad \qquad & e_b^{LFC} \in \mathbb{R}^+ \forall b\\
# \qquad \qquad & \alpha,\beta \in \mathbb{Z}^+\\
# \qquad \qquad & \mu_b \in \{0,1\} \forall b
# \end{align}
#
# El costo total $c^{tot}$ para el cumplimiento de la demanda para el día en particular
# $d$ consiste en el costo de la operación de la planta de energía, $c^{PP}$, el costo de la operación
# compra de energía del mercado spot, $c^{SM}$, y el costo de la compra de energía de la carga posterior al contrato, $c^{LFC}$. Por lo tanto, obtenemos por el costo total.
#
# # Indices
#
# | Indice | Nombre parametro | Descripcion |
# | ----------------|:---------:|-------------|
# | $t \in \mathfrak{T}:= {1,...,N^T}$ | $t$ | Conjunto de intervalos de tiempo por día. $N^T$ = 96 |
# | $m \in \mathfrak{M}:= {1,...,N^M}$ | $m$ | Conjunto para las etapas de nivel de potencia de la planta de energía. $N^M$ = 8 |
# | $b \in \mathfrak{B}:= {1,...,N^B}$ | $b$ | Conjunto de puntos de soporte de los precios de la zona para el LFC $N^B$ = 3 |
#
# # Variables
#
# | Variable | Nombre var | Unidad | Rango | Descripcion |
# | ----------------|---------|-------------|-------------|-------------|
# | $c^{tot}$ | c | euro | $\mathbb{R}^+$  |  Costo total  |
# | $c^{PP}$ | cPP | euro | $\mathbb{R}^+$  |  Costo asociado con el uso de la planta electrica  |
# | $e^{PP}$ | - | MWh | $\mathbb{R}^+$  |  Cantidad total de energía extraída de la planta de energía  |
# | $p_t^{PP}$ | pPP(t) | MW | $\mathbb{R}^+$  |  Cantidad de energía retirado de la planta de energía para tiempo t  |
# | $\delta_{mt}$ | delta(m,t) | - | ${0,1}$  |  Variable binaria con valor 1 si la central eléctrica está en el intervalo de tiempo t en la etapa m y 0 de lo contrario |
# | $\chi_t^{S}$ | chiS(t) |- | $\mathbb{R}^+$  |  Variable binaria con valor 1 si la central eléctrica cambia su etapa al comienzo del intervalo de tiempo t y 0 de lo contrario |
# | $\chi_t^{I}$ | chiI(t) |- | $\mathbb{R}^+$  |  Variable binaria con valor 1 si la central eléctrica se ha iniciado al principio del intervalo de tiempo t y 0 de lo contrario |
# | $c^{SM}$ | cSM | euro | $\mathbb{R}^+$  |  Costo por la compra de energía del mercado spot |
# | $e^{SM}$ | - | MWh | $\mathbb{R}^+$  | Energía comprada en el mercado spot |
# | $p_t^{SM}$ | pSM(t) | MW | $\mathbb{R}^+$  | La energía eléctrica del mercado spot para intervalo de tiempo t resultante de los contratos de carga máxima y de carga base |
# | $\alpha$ | alpha | - | $\mathbb{Z}^+$  |  Cantidad / proporción de los contratos de carga base de la contribución de cartera comprada en el mercado spot |
# | $\beta$ | beta | - | $\mathbb{Z}^+$  |  Cantidad / proporción de los contratos de carga máxima de la contribución de cartera comprada en el mercado spot |
# | $c^{LFC}$ | cLFC | euro | $\mathbb{R}^+$  |  Costo por la compra de energía de la carga siguiente contrato: tarifa de energía |
# | $e^{LFC}$ | eLFCtot | MWh | $\mathbb{R}^+$  |  Energía total de la carga según contrato |
# | $e_b^{LFC}$ | eLFCs(b) |MWh | $\mathbb{R}^+$  |  Contribución a la energía total de la LFC en el segmento b |
# | $p_t^{LFC}$ | pLFC(t) | MW | $\mathbb{R}^+$  | Potencia de la carga después del contrato por tiempo t |
# | $\mu_b$ | mu(b) | - | ${0,1}$  | Variables binarias con valor 1 si la cantidad diaria de energía comprada se encuentra entre $Z_{b-1}^d$ y $Z_b^d$|
#
#
# # Data Input
#
#
# | Variable | Nombre var | Unidad | Descripcion |
# | ----------------|---------|-------------|-------------|
# | $P_t$ |PowerForescast(t) | MW | Prediccion de la demanda de energia en base de cuartos de horas|
# | $C_{fix}^{PP}$ | - | euro | Costo fijo de la plnata de energía |
# | $C_{var}^{PP}$ | cPPvar | euro/MWh | Costos variables de la planta de energía|
# | $P_{max}^{PP}$ | pPPMax | MW | Capacidad de planta en MegaWatt |
# | $D_{act}^{PP}$ | - | - | Mínimo número de interavalos de tiempo entre dos etapas consecutivas |
# | $D_{idl}^{PP}$ | - | - | Número mínimo de intervalos de tiempo para que la planta permanezca en un período de inactividad |
# | $C^{BL}$ | cBL | euro/MWh | Costo por contrato de carga base comprado |
# | $C^{PL}$ | cPL | euro/MWh | Costo por contrato de carga pico comprado |
# | $C_{PR}^{LFC}$ | - | euro/MW | Costo por tasa de energía |
# | $C_{PR,year}^{LFC}$ | - | euro/MWh | Costo de la tasa de energía sobre una base anual |
# | $P_{ref}^{LFC}$ | pLFCref | MWh | Potencia eléctrica de referencia para carga según contrato |
# | $Z_b$ | eLFCbY(b) | MWh | Bordes anuales de zonas de cantidad para LFC |
# | $Z_b^d$ | eLFCb(b) | MWh | Bordes diarios de zonas de cantidad para LFC |
# | $P_b^{LFC}$ | cLFCvar(b) | euro/MWh | Costo / precio variable de LFC en el segmento b |
# | $C_b^{LFC}$ | cLFCs(b) | euro | Costo variable acumulado de LFC hasta el segmento b |
#
# # Restricciones
#
# ## Demanda de energía
#
# eq(23) Propone que se debe satisfacer la demanda de energia electrica para cada cuarto de hora:
#
# $$p_t^{PP} + p_t^{SM} + p_t^{LFC} = P_t  \quad t=1,..,N^T$$
#
# Recordar que la demanda de energía debe ser satisfecha exactamente. La razon es que
# (al menos una gran cantidad de) la energía no se puede almacenar.
#
# ## Energía de planta
#
# eq(7) El costo asociado con la planta de energía viene dado por la suma del costo fijo
# $C_{fix}^{PP}$ y el costo de la variable $C_{var}^{PP}$ por MWh. Recordar que el costo variable representan el costo de la energía producida y el costo fijo incluye el costo de la energía eléctrica; es decir, la capacidad de potencia de la planta influye en el costo de construcción de la planta que se incluyen en el costo fijo $C_{fix}^{PP}$. Entonces podemos escribir el costo total en euro como:
#
# $$c^{PP} = C_{fix}^{PP} + C_{var}^{PP}\sum_{t=1}^{N^T}\frac{1}{4}p_t^{PP}$$
#
# donde $p_t^{PP}$ representa la potencia eléctrica en MW de la central eléctrica durante el segmento de tiempo t, y esta se calcula con la restriccion eq(26)
#
# eq(25) Para modelar la estapa m de la planta electrica en el tiempo t, se introduce la variable bianria $\delta_{mt}$, La etapa m = 1 corresponde al estado inactivo de la central eléctrica. Valores $m = 2,...,N^M$ = 8 se refieren a las capacidades de utilizacion de 0.4, 0.5, 0.6, 0.7, 0.8, 0.9 y 1, respectivamente. La planta se encuentra exactamente en una de esas etapas en cualquier momento, es decir:
#
# $$\sum_{m=1}^{N^M}\delta_{mt} = 1 \quad t=1,..,N^T$$
#
# eq(27&28) ya que requisito de que cualquier etapa de potencia debe continuar durante al menos dos horas. Esta restricción se denomina restricción de tiempo de actividad mínima. Para este propósito, las variables binarias $\chi_t^S$ mantienen el rastro, si aquí hay un cambio en el nivel de la planta de energía en el segmento de tiempo t.
#
# $$\chi_t^{S} \geq \delta_{mt} - \delta_{mt-1} \quad \forall m\quad t=2,..,N^T$$
#
# $$\chi_t^{S} \geq \delta_{mt-1} - \delta_{mt} \quad \forall m\quad t=2,..,N^T$$
#
# eq(29) Las desigualdades eq(27) y eq(28) aseguran que la variable tiene valor 1, si hay un cambio en la etapa de la planta; sin embargo, $\chi_t^S$ también puede tener valor 1, si no hubo cambios en la etapa. Sólo es importante que ahora sea posible formular la condición
#
# $$\sum_{k=1}^{D_{act}^{PP}} \chi_{t+k-1}^{S} \leq 1 \quad t=1,..,N^T-(D_{act}^{PP}-1)$$
#
# asegurándose de que dentro de dos horas, o $D_{act}^{PP} = 8$ intervalos de tiempo, como máximo se produzca un cambio de etapa.
#
# El requisito para cualquier período de inactividad es de al menos cuatro horas. Esta condicion es
# llamado requisito de tiempo de inactividad mínimo o requisito de tiempo de inactividad mínimo. Si se ha iniciado la central eléctrica, es decir, si dejó el estado inactivo en el segmento de tiempo t. Obtenemos las siguientes desigualdades
#
# $$\chi_t^I \geq \delta_{1t-1} - \delta_{1t} \quad t= 2,...,N^T$$
#
# La condición para el período de inactividad, se puede modelar como
#
# $$\sum_{k=1}^{D_{idl}^{PP}} \chi_{t+k-1}^{I} \leq 1 \quad t=1,..,N^T-(D_{idl}^{PP}-1)$$
#
# con $D_{idl}^{PP} = 16$, o cuatro horas respectivamente. Esta restricción eq(31) puede ser interpretada
# en la forma en que la central eléctrica no puede dejar el estado inactivo más de una vez dentro de cualquier $ D_{idl}^{PP}$ parte de tiempo.
#
# # Mercado Spot
#
# eq(9) permita que $\alpha$ sea el número de carga base y $\beta$ sea el
# Número de contratos de carga máxima. La energía eléctrica comprada por intervalo de tiempo t (cuarto de hora) es entonces dado por
#
# $$ p_t^{SM} = \alpha +I_t^{PL}\beta $$
#
# eq(12) Como los contratos de energía eléctrica para la carga base ($\alpha$) y la carga máxima ($\beta$) son constantes, no hay costo adicional para la energía eléctrica asociada con los contratos de carga base y carga máxima.
#
# $$c^{SM} = 24C^{BL}\alpha + 12C^{PL}\beta $$
#
# # Contrato de seguimiento de carga
#
# eq(21) Coste de la potencia de la LFC según la tasa de energía.
#
# eq(16) Energía de LFC por un día a través de energía de LFC
#
# eq(18) Restricción en el segmento de precios.
#
# eq(19) Energía de la LFC durante un día a través de la energía de los diferentes segmentos.
#
# eq(20) Cantidad de energía acumulada para el primer segmento.
#
# eq(20) Cantidad de energía acumulada para todos los segmentos excepto el primero.

# %%
using JuMP, Gurobi;
using GLPKMathProgInterface;

solver = GurobiSolver()
# OutputFlag=0

#solver = GLPKSolverMIP(presolve=true)

# Set
t = [string("t$(i)") for i=1:96];

# Parameters

# electric power forecast
PowerForecast = Dict{String,Integer}(
"t1" => 287,"t2" => 275,"t3" => 262,"t4" => 250,"t5" => 255,"t6" => 260,"t7" => 265,"t8" => 270,"t9" => 267,"t10"=> 265,
"t11"=> 262,"t12"=> 260,"t13"=> 262,"t14"=> 265,"t15"=> 267,"t16"=> 270,"t17"=> 277,"t18"=> 285,"t19"=> 292,"t20"=> 300,
"t21"=> 310,"t22"=> 320,"t23"=> 330,"t24"=> 340,"t25"=> 357,"t26"=> 375,"t27"=> 392,"t28"=> 410,"t29"=> 405,"t30"=> 400,
"t31"=> 395,"t32"=> 390,"t33"=> 400,"t34"=> 410,"t35"=> 420,"t36"=> 430,"t37"=> 428,"t38"=> 427,"t39"=> 426,"t40"=> 425,
"t41"=> 432,"t42"=> 440,"t43"=> 447,"t44"=> 455,"t45"=> 458,"t46"=> 462,"t47"=> 466,"t48"=> 470,"t49"=> 466,"t50"=> 462,
"t51"=> 458,"t52"=> 455,"t53"=> 446,"t54"=> 437,"t55"=> 428,"t56"=> 420,"t57"=> 416,"t58"=> 412,"t59"=> 408,"t60"=> 405,
"t61"=> 396,"t62"=> 387,"t63"=> 378,"t64"=> 370,"t65"=> 375,"t66"=> 380,"t67"=> 385,"t68"=> 390,"t69"=> 383,"t70"=> 377,
"t71"=> 371,"t72"=> 365,"t73"=> 368,"t74"=> 372,"t75"=> 376,"t76"=> 380,"t77"=> 386,"t78"=> 392,"t79"=> 398,"t80"=> 405,
"t81"=> 408,"t82"=> 412,"t83"=> 416,"t84"=> 420,"t85"=> 413,"t86"=> 407,"t87"=> 401,"t88"=> 395,"t89"=> 386,"t90"=> 377, 
"t91"=> 368,"t92"=> 360,"t93"=> 345,"t94"=> 330,"t95"=> 315,"t96"=> 300 
);


# Power Plant (PP)
cPPvar = 25.0;    # variable cost of power plant [euro / MWh]
pPPMax = 300.0;   # maximal capacity of power plant      [MW]

# Set
 m = [string("m$(i)") for i=1:8];    # stage of the power plant
iS = [string("iS$(i)") for i=0:8];   # interval for constant PP operation
iI = [string("iI$(i)") for i=0:16];  # length of idle time period

# title Spot Market (SM)
cBL = 32.0; # cost for one base load contract [euro / MWh]
cPL = 41.0; # cost for one peak load contract [euro / MWh]

#Parameter IPL(t) indicator function for peak load contracts
IPL = Dict{String,Integer}();

for i=1:length(t)
    IPL[t[i]] = if (i>= 33 && i<= 80) 1 else 0 end;
end 

# title Load following Contract (LFC)
pLFCref = 400.0 # power reference level for the LFC

# Set
b = [string("b$(i)") for i=1:3];  # support points of the zone prices

# amount of energy at support point b
eLFCbY = Dict{String,Integer}(
"b1"=> 54750,
"b2"=> 182500,
"b3"=> 9000000
);

# specific energy price in segment b
cLFCvar = Dict{String,Integer}(
"b1"=> 80.0,
"b2"=> 65.0,
"b3"=> 52.0
);

# daily border of energy volumes for LFC
eLFCb = Dict{String,Float64}();

# calculate the daily borders of the energy volumes for the zones
for k in eLFCbY
    eLFCb[k[1]] = eLFCbY[k[1]]/365;
end

# accumulated cost for LFC up to segment b
cLFCs = Dict{String,Float64}();

# calculate the accumulated cost
cLFCs["b1"]         = 0;
cLFCs["b2"]         = cLFCvar["b1"]*eLFCb["b1"];

for i=3:length(b)
    cLFCs[b[i]] = cLFCs[b[i-1]] + cLFCvar[b[i-1]]*(eLFCb[b[i-1]] - eLFCb[b[i-2]]);
end


# variables

poutil = Model(solver=solver)

# total cost
@variable(poutil, c >= 0);

# cost of PP usage
@variable(poutil, cPP >= 0);

# power withdrawn from power plant
@variable(poutil, pPP[t] >= 0);

# indicate if the PP is in stage m at time t
@variable(poutil, delta[m,t] >= 0, Bin);

# indicator for segment b (for zone prices)
@variable(poutil, mu[b] >= 0, Bin);

# indicate if there is a PP stage change
@variable(poutil, chiS[t] >= 0);

# indicate if the PP left the idle stage
@variable(poutil, chiI[t] >= 0);

# cost of energy from SM
@variable(poutil, cSM >= 0);

# power from the spot market
@variable(poutil, pSM[t] >= 0);

# quantity of base load contracts
@variable(poutil, 0 <= alpha <= maximum([PowerForecast[i] for i=t]), Int);

# quantity of peak load contracts
@variable(poutil, 0 <= beta <= maximum([PowerForecast[i] for i=t]), Int);

# cost of LFC which is the enery rate
@variable(poutil, cLFC >= 0);

# total energy amount of LFC
@variable(poutil, eLFCtot >= 0);

# energy from LFC in segment b
@variable(poutil, eLFCs[b] >= 0);

# power from the LFC
@variable(poutil, 0 <= pLFC[t] <= pLFCref);

# CONSTRAINT

# the objective function: total cost; eq. (6)
@constraint(poutil, obj, c == cPP + cSM + cLFC);

# meet the power demand for each time period exactly; eq. (23)
@constraint(poutil, demand[i=t], pPP[i] + pSM[i] + pLFC[i] == PowerForecast[i]);

# (fix cost +) variable cost * energy amount produced; eq. (7) & (8)
@constraint(poutil, PPcost, cPP == cPPvar*sum(0.25*pPP[i] for i=t));

# power produced by the power plant; eq. (26)
@constraint(poutil, PPpower[i=t], pPP[i] == pPPMax * sum(0.1*(s + 2)*delta[m[s],i] for s=2:length(m)));

# the power plant is in exactly one stage at any time; eq. (25)
@constraint(poutil, PPstage[i=t], sum(delta[s,i] for s=m) == 1);

# next constraints model the minimum time period a power plant is in the
# same state and the constraint of the minimum idle time
# we need variable 'chiS' to find out when a status change takes place
# eq. (27)
@constraint(poutil, PPchiS1[i=2:length(t),j=1:length(m)],chiS[t[i]] >= delta[m[j],t[i]] - delta[m[j],t[i-1]]);

# second constraint for 'chiS' variable; eq. (28)
@constraint(poutil, PPchiS2[i=2:length(t),j=1:length(m)],chiS[t[i]] >= delta[m[j],t[i-1]] - delta[m[j],t[i]]);

# control the minimum change time period; eq. (29)
@constraint(poutil, PPstageChange[i=1:(length(t)-length(iS)+2)], sum(chiS[t[i + s]]  for s=0:(length(iS)-2)) <= 1);

# indicate if the plant left the idle state; eq. (30)
@constraint(poutil, PPstarted[i=2:length(t)],chiI[t[i]] >= delta["m1",t[i-1]] - delta["m1",t[i]]);

# control the minimum idle time period:
# it has to be at least Nk2 time periods long; eq. (31)
@constraint(poutil, PPidleTime[i=1:(length(t)-length(iI)+2)], sum(chiI[t[i + s]]  for s=0:(length(iI)-2)) <= 1);

# cost for the spot market; eq. (12)
# consistent of the base load (alpha) and peak load (beta) contracts
@constraint(poutil, SMcost, cSM == 24*cBL*alpha + 12*cPL*beta);

# Spot Market power contribution; eq. (9)
@constraint(poutil, SMpower[i=t], pSM[i] == alpha + IPL[i]*beta);

# cost of the LFC is given by the energy rate; eq. (14) & (21)
@constraint(poutil, LFCcost, cLFC == sum(cLFCs[i]*mu[i] + cLFCvar[i]*eLFCs[i] for i=b));

# total energy from the LFC; eq. (16)
# connect the eLFC(t) variables with eLFCtot
@constraint(poutil, LFCenergy, eLFCtot == 0.25*sum(pLFC));

# indicator variable 'mu':
# we are in exactly one price segment b; eq. (18)
@constraint(poutil, LFCmu, sum(mu) == 1);

# connect the 'mu' variables with the total energy amount; eq. (19)
@constraint(poutil, LFCenergyS, eLFCtot == sum(eLFCb[b[i-1]]*mu[b[i]]  for i=2:length(b)) + sum(eLFCs));

# accumulated energy amount for segment "b1"; eq. (20)
@constraint(poutil, LFCemuo, eLFCs["b1"] <= eLFCb["b1"]*mu["b1"]);

# accumulated energy amount for all other segments (then "b1"); eq. (20)
@constraint(poutil, LFCemug[i=2:length(b)],eLFCs[b[i]] <= (eLFCb[b[i]] - eLFCb[b[i-1]])*mu[b[i]]);

@objective(poutil, Min, c);

# %%
status = solve(poutil)
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 2179 rows, 1261 columns and 9139 nonzeros
# Variable types: 488 continuous, 773 integer (771 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 3e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 5e+02]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 178 rows and 148 columns
# Presolve time: 0.08s
# Presolved: 2001 rows, 1113 columns, 8463 nonzeros
# Variable types: 51 continuous, 1062 integer (880 binary)
# Found heuristic solution: objective 381138.00000
# Found heuristic solution: objective 300730.50000
#
# Root relaxation: objective 2.469847e+05, 1209 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 246984.718    0  310 300730.500 246984.718  17.9%     -    0s
# ...

# %%
#mostramos resultados
println("**** Status: ",status," Objective value: ", getobjectivevalue(poutil))
println("**** cPP    [euro] = ", getvalue(cPP))
println("**** ePP     [MWh] = ", sum(0.25*getvalue(pPP[i]) for i=t))
println("**** cSM    [euro] = ", getvalue(cSM))
println("**** eSM     [MWh] = ", sum(0.25*getvalue(pSM[i]) for i=t))
println("**** alpha         = ", getvalue(alpha))
println("**** beta          = ", getvalue(beta))
println("**** cLFC   [euro] = ", getvalue(cLFC))
println("**** eLFCtot [MWh] = ", getvalue(eLFCtot))
#println("**** pPP(t) [MW] = ", getvalue(pPP))
#println("**** delta(m,t)  = ", getvalue(delta))
#println("**** chiS        = ", getvalue(chiS))
#println("**** chiI        = ", getvalue(chiI))
#println("**** mu          = ", getvalue(mu))
#println("**** pSM         = ", getvalue(pSM))
#println("**** eLFCs(b)    = ", getvalue(eLFCs))
#println("**** pLFC(t)     = ", getvalue(pLFC))
# Out:
# **** Status: Optimal Objective value: 266388.0
# **** cPP    [euro] = 150750.0
# **** ePP     [MWh] = 6030.0
# **** cSM    [euro] = 71580.0
# **** eSM     [MWh] = 2220.0
# **** alpha         = 90.0
# **** beta          = 5.0
# **** cLFC   [euro] = 44058.0
# **** eLFCtot [MWh] = 679.0
